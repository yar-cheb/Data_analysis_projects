# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path='C:/Users/findl/OneDrive/Pulpit/Учебный материал и тестовые файлы/Time_Series_Project/individual_stocks_5yr'
company_list=['AAPL_data.csv','GOOG_data.csv','MSFT_data.csv','AMZN_data.csv']
all_data=pd.DataFrame()
for file in company_list:
    current_df=pd.read_csv(path+'/'+file)
    all_data=pd.concat([all_data,current_df])
all_data.shape
# Out:
# (4752, 7)

# %%
all_data.tail()
# Out:
#             date     open     high      low    close    volume  Name
# 1254  2018-02-01  1445.00  1459.88  1385.14  1390.00   9113808  AMZN
# 1255  2018-02-02  1477.39  1498.00  1414.00  1429.95  11125722  AMZN
# 1256  2018-02-05  1402.62  1458.98  1320.72  1390.00  11494985  AMZN
# 1257  2018-02-06  1361.46  1443.99  1351.79  1442.84  11066819  AMZN
# 1258  2018-02-07  1449.00  1460.99  1415.15  1416.78   7162741  AMZN

# %%
tech_list=all_data['Name'].unique()

# %%
all_data['date']=pd.to_datetime(all_data['date'])

# %%
plt.figure(figsize=(20,12))
for i,company in enumerate(tech_list,1):
    plt.subplot(2,2,i)
    df=all_data[all_data['Name']==company]
    plt.plot(df['date'],df['close'])
    plt.xticks(rotation='horizontal')
    plt.title(company)

# %%
import plotly.express as px

# %%
for company in tech_list:
    df=all_data[all_data['Name']==company]
    fig=px.line(df,x='date',y='volume',title=company)
    fig.show()
# Out:
# <div>                            <div id="b0028302-2bac-4b3b-a5bd-9a2275e5f6ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0028302-2bac-4b3b-a5bd-9a2275e5f6ec")) {                    Plotly.newPlot(                        "b0028302-2bac-4b3b-a5bd-9a2275e5f6ec",                        [{"hovertemplate": "date=%{x}<br>volume=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["2013-02-08T00:00:00", "2013-02-11T00:00:00", "2013-02-12T00:00:00", "2013-02-13T00:00:00", "2013-02-14T00:00:00", "2013-02-15T00:00:00", "2013-02-19T00:00:00", "2013-02-20T00:00:00", "2013-02-21T00:00:00", "2013-02-22T00:00:00", "2013-02-25T00:00:00", "2013-02-2
# ...

# %%
all_data['Daily price change']=all_data['close']-all_data['open']
all_data.head(20)
# Out:
#          date     open     high      low    close     volume  Name  \
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
# 5  2013-02-15  66.9785  67.1656  65.7028  65.7371   97924631  AAPL
# 6  2013-02-19  65.8714  66.1042  64.8356  65.7128  108854046  AAPL
# 7  2013-02-20  65.3842  65.3842  64.1142  64.1214  118891367  AAPL
# 8  2013-02-21  63.7142  64.1671  63.2599  63.7228  111596821  AAPL
# 9  2013-02-22  64.1785  64.5142  63.7999  64.4014   82583823  AAPL
# 10 2013-02-25  64.8356  65.0171  63.2242  63.2571   92899597  AAPL
# 11 2013-02-26  63.4028  64.5056  62.5228  64.1385  125096657  AAPL
# 12 2013-02-27  64.0614  64.6342  62.9499  63.5099  146674682  AAPL
# ...

# %%
all_data['1 day % return']=(all_data['close']-all_data['open'])/all_data['close']*100
all_data.head(20)
# Out:
#          date     open     high      low    close     volume  Name  \
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
# 5  2013-02-15  66.9785  67.1656  65.7028  65.7371   97924631  AAPL
# 6  2013-02-19  65.8714  66.1042  64.8356  65.7128  108854046  AAPL
# 7  2013-02-20  65.3842  65.3842  64.1142  64.1214  118891367  AAPL
# 8  2013-02-21  63.7142  64.1671  63.2599  63.7228  111596821  AAPL
# 9  2013-02-22  64.1785  64.5142  63.7999  64.4014   82583823  AAPL
# 10 2013-02-25  64.8356  65.0171  63.2242  63.2571   92899597  AAPL
# 11 2013-02-26  63.4028  64.5056  62.5228  64.1385  125096657  AAPL
# 12 2013-02-27  64.0614  64.6342  62.9499  63.5099  146674682  AAPL
# ...

# %%
for company in tech_list:
    df=all_data[all_data['Name']==company]
    fig=px.line(df,x='date',y='1 day % return',title=company)
    fig.show()
# Out:
# <div>                            <div id="d550a9d0-d907-4629-9639-5b39914df24b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d550a9d0-d907-4629-9639-5b39914df24b")) {                    Plotly.newPlot(                        "d550a9d0-d907-4629-9639-5b39914df24b",                        [{"hovertemplate": "date=%{x}<br>1 day % return=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["2013-02-08T00:00:00", "2013-02-11T00:00:00", "2013-02-12T00:00:00", "2013-02-13T00:00:00", "2013-02-14T00:00:00", "2013-02-15T00:00:00", "2013-02-19T00:00:00", "2013-02-20T00:00:00", "2013-02-21T00:00:00", "2013-02-22T00:00:00", "2013-02-25T00:00:00", "2
# ...

# %%
AAPL_data=all_data[all_data['Name']=='AAPL']

# %%
AAPL_data
# Out:
#                 open      high       low     close     volume  Name
# date
# 2013-02-08   67.7142   68.4014   66.8928   67.8542  158168416  AAPL
# 2013-02-11   68.0714   69.2771   67.6071   68.5614  129029425  AAPL
# 2013-02-12   68.5014   68.9114   66.8205   66.8428  151829363  AAPL
# 2013-02-13   66.7442   67.6628   66.1742   66.7156  118721995  AAPL
# 2013-02-14   66.3599   67.3771   66.2885   66.6556   88809154  AAPL
# ...              ...       ...       ...       ...        ...   ...
# 2018-02-01  167.1650  168.6200  166.7600  167.7800   47230787  AAPL
# 2018-02-02  166.0000  166.8000  160.1000  160.5000   86593825  AAPL
# 2018-02-05  159.1000  163.8800  156.0000  156.4900   72738522  AAPL
# 2018-02-06  154.8300  163.7200  154.0000  163.0300   68243838  AAPL
# 2018-02-07  163.0850  163.4000  159.0685  159.5400   51608580  AAPL
#
# [1259 rows x 6 columns]

# %%
AAPL_data['date']=pd.to_datetime(AAPL_data['date'])
AAPL_data.set_index('date',inplace=True)
AAPL_data.head()
# Out:
# <ipython-input-66-7f967530a4eb>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                open     high      low    close     volume  Name
# date
# 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
AAPL_data['2013-02-08':'2013-02-14']
# Out:
#                open     high      low    close     volume  Name
# date
# 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
AAPL_data['close'].resample('M').mean().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
AAPL_data['close'].resample('Y').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
aapl=pd.read_csv('C:/Users/findl/OneDrive/Pulpit/Учебный материал и тестовые файлы/Time_Series_Project/individual_stocks_5yr/AAPL_data.csv')
amzn=pd.read_csv('C:/Users/findl/OneDrive/Pulpit/Учебный материал и тестовые файлы/Time_Series_Project/individual_stocks_5yr/AMZN_data.csv')
msft=pd.read_csv('C:/Users/findl/OneDrive/Pulpit/Учебный материал и тестовые файлы/Time_Series_Project/individual_stocks_5yr/MSFT_data.csv')
goog=pd.read_csv('C:/Users/findl/OneDrive/Pulpit/Учебный материал и тестовые файлы/Time_Series_Project/individual_stocks_5yr/GOOG_data.csv')
aapl
amzn
msft
goog
# Out:
#            date      open     high      low    close   volume  Name
# 0    2014-03-27   568.000   568.00   552.92   558.46    13052  GOOG
# 1    2014-03-28   561.200   566.43   558.67   559.99    41003  GOOG
# 2    2014-03-31   566.890   567.00   556.93   556.97    10772  GOOG
# 3    2014-04-01   558.710   568.45   558.71   567.16     7932  GOOG
# 4    2014-04-02   565.106   604.83   562.19   567.00   146697  GOOG
# ..          ...       ...      ...      ...      ...      ...   ...
# 970  2018-02-01  1162.610  1174.00  1157.52  1167.70  2412114  GOOG
# 971  2018-02-02  1122.000  1123.07  1107.28  1111.90  4857943  GOOG
# 972  2018-02-05  1090.600  1110.00  1052.03  1055.80  3798301  GOOG
# 973  2018-02-06  1027.180  1081.71  1023.14  1080.60  3447956  GOOG
# 974  2018-02-07  1081.540  1081.78  1048.26  1048.58  2369232  GOOG
#
# [975 rows x 7 columns]

# %%
close=pd.DataFrame([aapl['close'],amzn['close'],msft['close'],goog['close']]).transpose()
close.columns=['aapl','amzn','msft','goog']
close
# Out:
#           aapl     amzn   msft    goog
# 0      67.8542   261.95  27.55  558.46
# 1      68.5614   257.21  27.86  559.99
# 2      66.8428   258.70  27.88  556.97
# 3      66.7156   269.47  28.03  567.16
# 4      66.6556   269.24  28.04  567.00
# ...        ...      ...    ...     ...
# 1254  167.7800  1390.00  94.26     NaN
# 1255  160.5000  1429.95  91.78     NaN
# 1256  156.4900  1390.00  88.00     NaN
# 1257  163.0300  1442.84  91.33     NaN
# 1258  159.5400  1416.78  89.61     NaN
#
# [1259 rows x 4 columns]

# %%
import seaborn as sns
sns.pairplot(data=close)

# %%
sns.heatmap(close.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
data=pd.DataFrame()
data['aapl_change']=(aapl['close']-aapl['open'])/aapl['close']*100
data['amzn_change']=(amzn['close']-amzn['open'])/amzn['close']*100
data['msft_change']=(msft['close']-msft['open'])/msft['close']*100
data['goog_change']=(goog['close']-goog['open'])/goog['close']*100
data.head(20)
# Out:
#     aapl_change  amzn_change  msft_change  goog_change
# 0      0.206325     0.209964     0.725953    -1.708269
# 1      0.714688    -2.328836     0.753769    -0.216075
# 2     -2.481344    -0.189409     0.000000    -1.781065
# 3     -0.042869     2.946525     0.356761     1.489879
# 4      0.443624     0.694548     0.427960     0.334039
# 5     -1.888431    -0.958165    -0.107105    -0.019307
# 6     -0.241353     1.423540     0.587984    -5.801451
# 7     -1.969389    -1.422619    -0.932903    -0.481278
# 8      0.013496     0.308340    -0.909422     2.216616
# 9      0.346110    -0.452114     0.288184     0.801220
# 10    -2.495372    -2.720591    -2.192181    -4.445882
# 11     1.147049    -0.589914    -0.036536    -0.367508
# 12    -0.868369     1.462488     1.402373    -1.076016
# 13    -0.600408     0.930866    -0.287770    -0.070837
# 14    -1.749228     0.929480     0.822898     2.432889
# 15    -1.844948     2.837684     1.065719    -2.370826
# ...

# %%
data.shape
# Out:
# (1259, 4)

# %%
sns.pairplot(data=data)

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.displot(data['aapl_change'])

# %%
data['aapl_change'].std()
# Out:
# 1.1871377131421237

# %%
data['aapl_change'].std()*2
# Out:
# 2.3742754262842474

# %%
data['aapl_change'].std()*3
# Out:
# 3.561413139426371

# %%
 data['aapl_change'].quantile(0.1)
# Out:
# -1.4246644227944307

# %%
data.describe().T
# Out:
#               count      mean       std       min       25%       50%  \
# aapl_change  1259.0 -0.000215  1.187138 -7.104299 -0.658021  0.042230
# amzn_change  1259.0 -0.000398  1.358679 -9.363077 -0.738341 -0.002623
# msft_change  1259.0  0.076404  1.059260 -5.177618 -0.509241  0.061069
# goog_change   975.0 -0.012495  1.092560 -5.952266 -0.551963  0.024951
#
#                   75%       max
# aapl_change  0.715427  8.000388
# amzn_change  0.852568  5.640265
# msft_change  0.703264  4.861491
# goog_change  0.672649  4.943550
